# %% [markdown]
# # Lecture 9 — Streamlit Foundations
# ## From Charts to Dashboards
#
# > **Dataset:** World Happiness Report 2023
#
# > **Big Book of Dashboards:** Introduction + Chapter 1 — What is a dashboard?

# %% [markdown]
# ---
# ## Opening: Model Answer Review

# %% [markdown]
# ---
# ## Design Principles - Part I: What Is a Dashboard?

# %% [markdown]
# ### 💡 The BBD definition:  A dashboard is a visual display of data used to monitor conditions and/or facilitate understanding.
#
# ### 💡 Two things matter in this definition:
#
# 1. It must be visual — numbers in a table are not a dashboard
# 2. It must have a purpose — monitoring OR understanding. If you cannot say which of these your dashboard does, you do not yet have a dashboard idea, you have a data collection
#
# ### 💡 Chart vs Dashboard — the key difference
#
# | | Chart | Dashboard |
# |---|---|---|
# | Answers | One question | Multiple related questions simultaneously |
# | Audience | Anyone | A specific person or role |
# | Usage | Once, to make a point | Repeatedly, to monitor over time |
# | Filters | None to minimal | User-controlled |
# | Success measure | Did the audience understand the message? | Does the audience return to use it? |
#
#
# ### 💡 The single-purpose rule
#
# Before any code, write this sentence:
#
# > ❌ *'This dashboard shows the World Happiness data.'* (topic, not purpose)
# > ✅ *'This dashboard helps a UN policy analyst see which countries lead on happiness and what factors drive the gap.'* (audience + purpose)

# %% [markdown]
# ---
# ## Design Principles - Part II: BBD Preattentive Attributes + Colour

# %% [markdown]
# ### 💡 Preattentive attributes
#
# - BBD (chapter 1) and SWD (chapter 4) say the same thing independently: our brains process certain visual properties in under 250 milliseconds, before conscious attention
# - Both books agree: colour, size, and length are the most powerful preattentive attributes. Use them deliberately on every dashboard element
#
# ### 💡 The 4 colour types
#
# | Type | When to use | Example |
# |---|---|---|
# | **Sequential** | One direction, ordered data | Sales by state: light→dark blue = low→high |
# | **Diverging** | Two directions from a midpoint | Profit: blue (positive) ↔ red (negative), white = zero |
# | **Categorical** | Unordered groups | Continent colours on a scatter plot |
# | **Highlight** | One thing that needs to stand out | The one bar or line you want the audience to look at first |

# %% [markdown]
# ---
# ## Let's Code Some Examples 💻
#
# > **HOW TO RUN:** Copy each block into `app.py`, run `streamlit run app.py`.

# %%
import streamlit as st
import pandas as pd

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.58.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<8,>=5.5 (from streamlit)
#   Downloading cachetools-7.1.4-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit) (8.4.1)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.50-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\hp\anaconda3\lib\site-packages (from streamlit) (2.0.1)
# Requirement already satisfied: packaging>=20 in c:\users\hp\anaconda3\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<4,>=1.4.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit) (11.1.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: protobuf<8,>=3.20 in c:\users\hp\anaconda3\lib\site-packages (from streamlit) (5.29.3)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-24.0.0-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\hp\anaconda3\lib\site-packages (from streamlit) (2.32.5)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit) (4.15.0)
# Collecting starlette>=0.40.0 (from streamlit)
#   Downloading starlette-1.2.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting uvicorn>=0.30.0 (from streamlit)
#   Downloading uvicorn-0.49.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting httptools>=0.6.3 (from streamlit)
#   Downloading httptools-0.8.0-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: anyio>=4.0.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit) (4.10.0)
# Collecting python-multipart>=0.0.10 (from streamlit)
#   Downloading python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: websockets>=12.0.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit) (16.0)
# Collecting itsdangerous>=2.1.2 (from streamlit)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\hp\anaconda3\lib\site-packages (from streamlit) (4.0.2)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\hp\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=2.4.0 in c:\users\hp\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.7.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from anyio>=4.0.0->streamlit) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in c:\users\hp\anaconda3\lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
# Downloading streamlit-1.58.0-py3-none-any.whl (9.2 MB)
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.2 MB 2.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.2 MB 2.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.2 MB 2.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.4/9.2 MB 2.5 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.2 MB 2.7 MB/s eta 0:00:03
#    --------------- ------------------------ 3.7/9.2 MB 2.7 MB/s eta 0:00:03
#    ------------------ --------------------- 4.2/9.2 MB 2.7 MB/s eta 0:00:02
#    -------------------- ------------------- 4.7/9.2 MB 2.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.5/9.2 MB 2.8 MB/s eta 0:00:02
#    -------------------------- ------------- 6.0/9.2 MB 2.7 MB/s eta 0:00:02
#    --------------------------- ------------ 6.3/9.2 MB 2.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.8/9.2 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.2 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.9/9.2 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 8.7/9.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 2.7 MB/s eta 0:00:00
# Downloading altair-6.1.0-py3-none-any.whl (796 kB)
#    ---------------------------------------- 0.0/797.0 kB ? eta -:--:--
#    ---------------------------------------  786.4/797.0 kB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 797.0/797.0 kB 2.9 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-7.1.4-py3-none-any.whl (16 kB)
# Downloading gitpython-3.1.50-py3-none-any.whl (212 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 2.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/11.3 MB 3.7 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.3 MB 3.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/11.3 MB 3.4 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/11.3 MB 3.4 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.3 MB 3.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.3 MB 3.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.3 MB 3.0 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.3 MB 3.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.3 MB 3.1 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.3 MB 3.1 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.3 MB 3.2 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.3 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.3 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.3 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.3 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 3.1 MB/s eta 0:00:00
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading httptools-0.8.0-cp312-cp312-win_amd64.whl (90 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading pyarrow-24.0.0-cp312-cp312-win_amd64.whl (27.4 MB)
#    ---------------------------------------- 0.0/27.4 MB ? eta -:--:--
#    - -------------------------------------- 0.8/27.4 MB 3.7 MB/s eta 0:00:08
#    -- ------------------------------------- 1.6/27.4 MB 3.4 MB/s eta 0:00:08
#    --- ------------------------------------ 2.4/27.4 MB 3.8 MB/s eta 0:00:07
#    ---- ----------------------------------- 3.4/27.4 MB 3.9 MB/s eta 0:00:07
#    ------ --------------------------------- 4.2/27.4 MB 3.9 MB/s eta 0:00:06
#    ------- -------------------------------- 5.0/27.4 MB 4.0 MB/s eta 0:00:06
#    -------- ------------------------------- 6.0/27.4 MB 4.1 MB/s eta 0:00:06
#    --------- ------------------------------ 6.8/27.4 MB 4.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 7.6/27.4 MB 4.0 MB/s eta 0:00:05
#    ------------ --------------------------- 8.7/27.4 MB 4.1 MB/s eta 0:00:05
#    ------------- -------------------------- 9.4/27.4 MB 4.1 MB/s eta 0:00:05
#    -------------- ------------------------- 10.2/27.4 MB 4.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 11.0/27.4 MB 4.1 MB/s eta 0:00:04
#    ----------------- ---------------------- 11.8/27.4 MB 4.1 MB/s eta 0:00:04
#    ------------------ --------------------- 12.3/27.4 MB 4.0 MB/s eta 0:00:04
#    ------------------- -------------------- 13.4/27.4 MB 4.0 MB/s eta 0:00:04
#    -------------------- ------------------- 14.2/27.4 MB 4.0 MB/s eta 0:00:04
#    --------------------- ------------------ 14.9/27.4 MB 4.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 15.7/27.4 MB 3.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 16.3/27.4 MB 3.9 MB/s eta 0:00:03
#    ------------------------ --------------- 16.8/27.4 MB 3.9 MB/s eta 0:00:03
#    ------------------------- -------------- 17.3/27.4 MB 3.8 MB/s eta 0:00:03
#    -------------------------- ------------- 18.1/27.4 MB 3.8 MB/s eta 0:00:03
#    --------------------------- ------------ 18.9/27.4 MB 3.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 19.4/27.4 MB 3.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 19.9/27.4 MB 3.7 MB/s eta 0:00:03
#    ------------------------------ --------- 21.0/27.4 MB 3.7 MB/s eta 0:00:02
#    ------------------------------- -------- 21.5/27.4 MB 3.7 MB/s eta 0:00:02
#    -------------------------------- ------- 22.3/27.4 MB 3.7 MB/s eta 0:00:02
#    --------------------------------- ------ 23.1/27.4 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 23.9/27.4 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------ --- 24.6/27.4 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 25.4/27.4 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 26.2/27.4 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  27.0/27.4 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  27.3/27.4 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 27.4/27.4 MB 3.6 MB/s eta 0:00:00
# Downloading python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Downloading starlette-1.2.1-py3-none-any.whl (73 kB)
# Downloading uvicorn-0.49.0-py3-none-any.whl (71 kB)
# Installing collected packages: toml, tenacity, smmap, python-multipart, pyarrow, itsdangerous, httptools, cachetools, blinker, uvicorn, starlette, pydeck, gitdb, gitpython, altair, streamlit
#
#    -- -------------------------------------  1/16 [tenacity]
#    ------- --------------------------------  3/16 [python-multipart]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    ---------- -----------------------------  4/16 [pyarrow]
#    --------------- ------------------------  6/16 [httptools]
#    -------------------- -------------------  8/16 [blinker]
#    ---------------------- -----------------  9/16 [uvicorn]
#    ---------------------- -----------------  9/16 [uvicorn]
#    ------------------------- -------------- 10/16 [starlette]
#    ------------------------- -------------- 10/16 [starlette]
#    --------------------------- ------------ 11/16 [pydeck]
#    --------------------------- ------------ 11/16 [pydeck]
#    --------------------------- ------------ 11/16 [pydeck]
#    ------------------------------ --------- 12/16 [gitdb]
#    ------------------------------ --------- 12/16 [gitdb]
#    -------------------------------- ------- 13/16 [gitpython]
#    -------------------------------- ------- 13/16 [gitpython]
#    -------------------------------- ------- 13/16 [gitpython]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ---------------------------------------- 16/16 [streamlit]
#
# Successfully installed altair-6.1.0 blinker-1.9.0 cachetools-7.1.4 gitdb-4.0.12 gitpython-3.1.50 httptools-0.8.0 itsdangerous-2.2.0 pyarrow-24.0.0 pydeck-0.9.2 python-multipart-0.0.32 smmap-5.0.3 starlette-1.2.1 streamlit-1.58.0 tenacity-9.1.4 toml-0.10.2 uvicorn-0.49.0

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
df = pd.read_csv('../data/world_happiness_2023.csv')

df.head()
# Out:
#   Country name            Regional indicator  Ladder score  \
# 0      Finland                Western Europe         7.804
# 1      Denmark                Western Europe         7.586
# 2      Iceland                Western Europe         7.525
# 3       Israel  Middle East and North Africa         7.473
# 4  Netherlands                Western Europe         7.464
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     71.9
# 1                 10.933           0.954                     72.7
# 2                 10.878           0.983                     72.5
# 3                 10.527           0.916                     72.4
# 4                 11.015           0.939                     72.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.949       0.142                      0.179
# 1                         0.931       0.168                      0.234
# 2                         0.961       0.260                      0.150
# 3                         0.903       0.149                      0.826
# 4                         0.879       0.240                      0.296

# %%
print(dir(st))
# Out:
# ['App', 'Page', '_BottomContainerProxy', '_ContextProxy', '_DeltaGenerator', '_DeltaGeneratorSingleton', '_Dialog', '_ExpanderContainer', '_PopoverContainer', '_QueryParamsProxy', '_STREAMLIT_VERSION_STRING', '_SessionStateProxy', '_StatusContainer', '_TabContainer', '_UserInfoProxy', '__annotations__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_bidi_component', '_bottom', '_bottom_dg_internal', '_cache', '_cache_data', '_cache_resource', '_cast', '_column_config', '_config', '_connection', '_deprecate_obj_name', '_dg_singleton', '_dialog_decorator', '_event', '_fragment', '_gather_metrics', '_logger', '_login', '_logout', '_main', '_os', '_secrets_singleton', '_update_logger', 'altair_chart', 'area_chart', 'audio', 'audio_input', 'auth_util', 'badge', 'balloons', 'bar_chart', 'bokeh_chart', 'bottom', 'button', 'cache', 'cache_data', 'cache_resource', 'camera_input', 'caption', 'chat_input', 'chat_message', 'checkbox', 'cli_util', 'code', 'color_picker', 'column_config', 'columns', 'commands', 'components', 'config', 'config_option', 'config_util', 'connection', 'connections', 'container', 'context', 'cursor', 'data_editor', 'dataframe', 'dataframe_util', 'date_input', 'datetime_input', 'delta_generator', 'delta_generator_singletons', 'deprecation_util', 'development', 'dialog', 'divider', 'download_button', 'echo', 'elements', 'empty', 'env_util', 'error', 'error_util', 'errors', 'exception', 'expander', 'feedback', 'file_uploader', 'file_util', 'form', 'form_submit_button', 'fragment', 'get_option', 'graphviz_chart', 'header', 'help', 'html', 'iframe', 'image', 'info', 'json', 'latex', 'line_chart', 'link_button', 'logger', 'login', 'logo', 'logout', 'map', 'markdown', 'menu_button', 'metric', 'multiselect', 'navigation', 'net_util', 'number_input', 'page_link', 'pagination', 'path_security', 'pdf', 'pills', 'plotly_chart', 'popover', 'progress', 'proto', 'pydeck_chart', 'pyplot', 'query_params', 'radio', 'rerun', 'runtime', 'scatter_chart', 'secrets', 'segmented_control', 'select_slider', 'selectbox', 'session_state', 'set_option', 'set_page_config', 'sidebar', 'slider', 'snow', 'source_util', 'space', 'spinner', 'starlette', 'status', 'stop', 'streamlit', 'string_util', 'subheader', 'success', 'switch_page', 'table', 'tabs', 'text', 'text_area', 'text_input', 'time_input', 'time_util', 'title', 'toast', 'toggle', 'type_util', 'url_util', 'user', 'user_info', 'util', 'vega_lite_chart', 'version', 'video', 'warning', 'watcher', 'web', 'write', 'write_stream']

# %%
# ── STEP 1: Minimal working app ──────────────────────────────────────────
import streamlit as st
import pandas as pd
import plotly.express as px

df = pd.read_csv('../data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

st.title("World Happiness Dashboard")
st.write(f"Data loaded: {len(df)} countries")
# Out:
# 2026-06-05 15:55:37.058 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:37.523
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\HP\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-05 15:55:37.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:37.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:37.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:37.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:37.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# ── STEP 2: Add a chart + apply appropriate colour rule ───────────────────────────
import streamlit as st
import pandas as pd
import plotly.express as px

df = pd.read_csv('../data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

st.title("World Happiness Dashboard")

top15 = df.nlargest(15, 'Score').sort_values('Score')

# The bars are ordered, not categorical — sequential blue (light→dark) is appropriate
fig = px.bar(top15, x='Score', y='Country', orientation='h',
             color='Score',
             color_continuous_scale='Blues',  
             range_color=[5.0, 8.5],
             labels={'Score': 'Happiness Score (0–10)', 'Country': ''})
fig.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                  font=dict(family='Arial', size=12),
                  xaxis=dict(range=[0, 8.5]),  
                  coloraxis_showscale=False,
                  margin=dict(l=10,r=20,t=10,b=10))
fig.update_traces(marker_line_width=0)
fig.show()
st.plotly_chart(fig, width='stretch')  # always use this
# Out:
# 2026-06-05 15:55:43.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:43.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:43.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:48.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:48.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:48.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:48.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:55:48.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# !pip install plotly.express
# Out:
# Collecting plotly.express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\hp\anaconda3\lib\site-packages (from plotly.express) (2.2.3)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\hp\anaconda3\lib\site-packages (from plotly.express) (6.7.0)
# Collecting statsmodels>=0.9.0 (from plotly.express)
#   Downloading statsmodels-0.14.6-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: scipy>=0.18 in c:\users\hp\anaconda3\lib\site-packages (from plotly.express) (1.17.1)
# Collecting patsy>=0.5 (from plotly.express)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy>=1.11 in c:\users\hp\anaconda3\lib\site-packages (from plotly.express) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\hp\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly.express) (2.7.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly.express) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly.express) (1.17.0)
# Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading statsmodels-0.14.6-cp312-cp312-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.5 MB 6.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.5 MB 6.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.5 MB 6.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.5/9.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 6.3 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels, plotly.express
#
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ---------------------------------------- 3/3 [plotly.express]
#
# Successfully installed patsy-1.0.2 plotly.express-0.4.1 statsmodels-0.14.6

# %%
# ── STEP 3: Sidebar filter + reactive chart ──────────────────────────────
import streamlit as st
import pandas as pd
import plotly.express as px

df = pd.read_csv('../data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

st.title("World Happiness Dashboard")

with st.sidebar:
    st.header("Filters")
    regions = ['All'] + sorted(df['Region'].unique().tolist())
    selected_region = st.selectbox("Region", regions)
    top_n = st.slider("Show top N countries", 5, 25, 15)

filtered = df if selected_region == 'All' else df[df['Region'] == selected_region]
top = filtered.nlargest(top_n, 'Score').sort_values('Score')

fig = px.bar(top, x='Score', y='Country', orientation='h',
             color_discrete_sequence=['#2E75B6'],  
             labels={'Score': 'Happiness Score (0–10)', 'Country': ''})

fig.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                  xaxis=dict(range=[0,8.5], gridcolor='#EEEEEE'),
                  yaxis=dict(showgrid=False),
                  font=dict(family='Arial', size=12),
                  margin=dict(l=10,r=20,t=10,b=10))

fig.update_traces(marker_line_width=0)

st.plotly_chart(fig, width='stretch')
# Out:
# 2026-06-05 15:57:24.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.280 Session state does not function when running a script without `streamlit run`
# 2026-06-05 15:57:24.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:24.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# ── STEP 4: Full dashboard — KPIs + columns layout + BBD colour ──────────
import streamlit as st
import pandas as pd
import plotly.express as px

st.set_page_config(page_title="World Happiness", page_icon="🌍", layout="wide")

df = pd.read_csv('../data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

with st.sidebar:
    st.header("Filters")
    regions = ['All'] + sorted(df['Region'].unique().tolist())
    selected_region = st.selectbox("Region", regions)
    top_n = st.slider("Show top N", 5, 25, 15)

filtered = df if selected_region == 'All' else df[df['Region'] == selected_region]

st.title("🌍 World Happiness Dashboard")
st.caption("Source: World Happiness Report 2023 | Kaggle")

# KPI row — BBD: big numbers at the top, readable in 5 seconds
col1, col2, col3 = st.columns(3)
col1.metric("Countries", len(filtered))
col2.metric("Avg Score", f"{filtered['Score'].mean():.2f}",
            f"{filtered['Score'].mean()-df['Score'].mean():+.2f} vs global")
col3.metric("Happiest", filtered.nlargest(1,'Score')['Country'].values[0])

st.divider()

# Two-column layout
col_left, col_right = st.columns(2)

with col_left:
    st.subheader("Rankings")
    top = filtered.nlargest(top_n, 'Score').sort_values('Score')
    
    fig1 = px.bar(top, x='Score', y='Country', orientation='h',
                  color_discrete_sequence=['#2E75B6'],
                  labels={'Score':'Score (0–10)','Country':''})
    
    fig1.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                       xaxis=dict(range=[0,8.5]), font=dict(family='Arial',size=12),
                       margin=dict(l=10,r=10,t=5,b=10))
    fig1.update_traces(marker_line_width=0)
    st.plotly_chart(fig1, width='stretch')

with col_right:
    st.subheader("Score vs GDP")
    fig2 = px.scatter(filtered, x='GDP', y='Score', hover_name='Country',
                      # BBD categorical colour: continent = unordered group
                      color_discrete_sequence=['#E63946'])
    fig2.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                       font=dict(family='Arial',size=12),
                       margin=dict(l=10,r=10,t=5,b=10))
    st.plotly_chart(fig2, width='stretch')

st.divider()
st.caption("Built with Streamlit + Plotly")
# Out:
# 2026-06-05 15:57:32.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:32.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:32.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:32.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:32.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:32.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:32.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:32.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:32.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:32.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:32.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 15:57:33.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# ---
# ## Class Exercise 💪 💻

# %%
# ── STEP 6: Add a third chart of your choice using a DIVERGING colour scale ───────────────────────────
# something where values go above and below a meaningful midpoint
# Label the midpoint in an annotation.

# %%
# ── STEP 6: Deploy to Streamlit Community Cloud ───────────────────────────
# 1. Save as app.py in your GitHub repo
# 2. Create requirements.txt:
#       streamlit
#       plotly
#       pandas
# 3. share.streamlit.io → New app → point to repo/app.py
# 4. Done — public URL in ~2 minutes

# For data: either commit to repo, or load from raw GitHub URL:
# df = pd.read_csv('https://raw.githubusercontent.com/USER/REPO/main/data/file.csv')
